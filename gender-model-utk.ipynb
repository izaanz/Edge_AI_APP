# %%
import tensorflow as tf
import numpy as np
import cv2
import os, glob
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
# --- Helper function for plotting ---
def plot_history(history, title, save_path):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title(f'{title} - Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title(f'{title} - Loss')

    plt.savefig(save_path)
    plt.show()

# %% [markdown]
# **This notebook was created on kaggle. Make sure the dataset UTKFace from Sanjaya Subedi is added as input already in kaggle.**

# %%
# CONFIG

DATASET_PATH = "/kaggle/input/utkface-new"   # Kaggle dataset mount
MODEL_PATH = "/kaggle/working/gender_model.h5"
IMG_WIDTH_AGE_GENDER = 128
IMG_HEIGHT_AGE_GENDER = 128
BATCH_SIZE = 32

# %%
# Get file paths and labels - I am doing it seperately here since I want to make sure all the files are properly detected
def get_gender_paths_and_labels():
    print("Scanning UTKFace for gender data...")
    paths, genders = [], []
    all_files = glob.glob(os.path.join(DATASET_PATH, "**/*.jpg"), recursive=True)
    print(f"Found {len(all_files)} images")

    for filepath in all_files:
        try:
            parts = os.path.basename(filepath).split('_')
            gender = int(parts[1])  # 0 = male, 1 = female
            paths.append(filepath)
            genders.append(gender)
        except:
            continue
    return paths, genders

# %%
# Creating the tf pipeling, well sort of.

def parse_image_gender(filename, gender):
    image = tf.io.read_file(filename)
    image = tf.io.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [IMG_WIDTH_AGE_GENDER, IMG_HEIGHT_AGE_GENDER])
    image = image / 255.0
    return image, gender

def create_dataset(paths, labels, training=False):
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    ds = ds.map(parse_image_gender, num_parallel_calls=tf.data.AUTOTUNE)
    if training:
        ds = ds.shuffle(1000)
    return ds.batch(BATCH_SIZE).cache().prefetch(tf.data.AUTOTUNE)

# %%
# for building gender model

def build_gender_model():
    base_model = tf.keras.applications.MobileNetV2(
        input_shape=(IMG_WIDTH_AGE_GENDER, IMG_HEIGHT_AGE_GENDER, 3),
        include_top=False, weights='imagenet'
    ) # building on top of MobileNetV2
    base_model.trainable = False  # freeze feature extractor
    
    model = tf.keras.Sequential([
        base_model,
        tf.keras.layers.GlobalAveragePooling2D(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) # basics - b_crossentropy since we have 0 and 1 only
    return model

# %%
# fun part - training and evaluation

print("--- Training and Evaluating Gender Model ---")
paths, genders = get_gender_paths_and_labels()

# Stratified split
X_train_val, X_test, y_train_val, y_test = train_test_split(
    paths, genders, test_size=0.2, random_state=42, stratify=genders
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size=0.25, random_state=42, stratify=y_train_val
)

print(f"Train: {len(X_train)}, Val: {len(X_val)}, Test: {len(X_test)}")

# Create datasets
train_ds = create_dataset(X_train, y_train, training=True)
val_ds = create_dataset(X_val, y_val)
test_ds = create_dataset(X_test, y_test)

# Build + Train
gender_model = build_gender_model()
history = gender_model.fit(
    train_ds,
    epochs=15,
    validation_data=val_ds,
    verbose=1
)


# Save Model
gender_model.save(MODEL_PATH)
print(f"✅ Gender model saved at {MODEL_PATH}")

# Saving a .tflite version as well

loaded = tf.keras.models.load_model(MODEL_PATH)  
converter = tf.lite.TFLiteConverter.from_keras_model(loaded)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_from_h5 = converter.convert()
open("gender_model_from_saved.tflite", "wb").write(tflite_from_h5)
print("Saved gender_model_from_saved.tflite")
# Out:
# --- Training and Evaluating Gender Model ---
# Scanning UTKFace for gender data...
# Found 66976 images
# Train: 40185, Val: 13395, Test: 13396
# I0000 00:00:1756594527.442555      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1756594527.443276      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1756594539.090525     108 service.cc:148] XLA service 0x7c88bc0527d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1756594539.091858     108 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1756594539.091877     108 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1756594540.103558     108 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    4/1256 ━━━━━━━━━━━━━━━━━━━━ 55s 44ms/step - accuracy: 0.5384 - loss: 1.0740
# I0000 00:00:1756594544.577911     108 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 106s 73ms/step - accuracy: 0.7627 - loss: 0.4934 - val_accuracy: 0.8245 - val_loss: 0.3695
# Epoch 2/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 18s 15ms/step - accuracy: 0.8186 - loss: 0.3912 - val_accuracy: 0.8405 - val_loss: 0.3424
# Epoch 3/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8331 - loss: 0.3635 - val_accuracy: 0.8458 - val_loss: 0.3316
# Epoch 4/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8404 - loss: 0.3482 - val_accuracy: 0.8514 - val_loss: 0.3245
# Epoch 5/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8510 - loss: 0.3302 - val_accuracy: 0.8596 - val_loss: 0.3065
# Epoch 6/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8587 - loss: 0.3192 - val_accuracy: 0.8625 - val_loss: 0.3067
# Epoch 7/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8679 - loss: 0.3003 - val_accuracy: 0.8785 - val_loss: 0.2839
# Epoch 8/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8722 - loss: 0.2917 - val_accuracy: 0.8773 - val_loss: 0.2797
# Epoch 9/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8752 - loss: 0.2814 - val_accuracy: 0.8854 - val_loss: 0.2713
# Epoch 10/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8841 - loss: 0.2685 - val_accuracy: 0.8829 - val_loss: 0.2746
# Epoch 11/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8875 - loss: 0.2558 - val_accuracy: 0.8982 - val_loss: 0.2519
# Epoch 12/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8936 - loss: 0.2460 - val_accuracy: 0.8915 - val_loss: 0.2631
# Epoch 13/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.8974 - loss: 0.2375 - val_accuracy: 0.9027 - val_loss: 0.2457
# Epoch 14/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9007 - loss: 0.2266 - val_accuracy: 0.9066 - val_loss: 0.2386
# Epoch 15/15
# 1256/1256 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.9046 - loss: 0.2193 - val_accuracy: 0.9092 - val_loss: 0.2291
# ✅ Gender model saved at /kaggle/working/gender_model.h5
# Saved artifact at '/tmp/tmpv_s1wd_b'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   136929495696784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495708688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495709072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495708880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495707536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495710224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495710608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495711376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495710800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495703888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495709456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999921680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999920720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495709840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999920912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999923024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999923408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999923792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999923600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999921104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999924944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999925328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999925712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999925520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999921488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999926864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999927248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999927632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999927440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999922640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999928784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999929168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999929552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999929360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999924560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999930704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999931088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999931472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999931280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999926480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929509681168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999932624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999921872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495707344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136929495697936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999933200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999933584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999933968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999933776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999930320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999935120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999935504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999935888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999935696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999931856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999932816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000183824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000182864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999934736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999934352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000184784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000185168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000185552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000185360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000183248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000186704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000187088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000187472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000187280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000184016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000188624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000189008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000189392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000189200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000184400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000190544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000190928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000191312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000191120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000186320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000192464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000192848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000193232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000193040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000188240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000194384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000194768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000195152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000194960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000190160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000196304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000196688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000197072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000196880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000192080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000198224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000197840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000197456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000198800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000194000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000195920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000429968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000430352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000430160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000429200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000431504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000431888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000432272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000432080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000429392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000433424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000433808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000434192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000434000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000428624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000435344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000435728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000436112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000435920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000431120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000437264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000437648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000438032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000437840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000433040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000439184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000439568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000439952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000439760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000434960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000441104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000441488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000441872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000441680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000436880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000443024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000443408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000443792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000443600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000438800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000440720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000674576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000675344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000442640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000442256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000676304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000676688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000677072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000676880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000675536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000678224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000678608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000678992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000678800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000674384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000680144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000680528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000680912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000680720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000675920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000682064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000682448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000682832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000682640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000677840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000683984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000684368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000684752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000684560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000679760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000685904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000686288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000686672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000686480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000681680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000687824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000688208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000688592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000688400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000683600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000689744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000689360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000688976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000690320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000685520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136927000687440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998889872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998890256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998890064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998888528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998891408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998891792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998892176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998891984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998889296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998893328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998893712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998894096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998893904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998888912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998895248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998895632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998896016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998895824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998891024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998897168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998897552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998897936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998897744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998892944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998899088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998899472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998899856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998899664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998901008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998901392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998901776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998901584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998896784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998902928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998903312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998903696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998903504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998898704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998900624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999151056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999151632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998902544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926998902160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999152592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999152976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999153360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999153168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999151824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999154512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999154896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999155280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999155088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999150864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999156432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999156816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999157200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999157008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999152208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999158352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999158736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999159120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999158928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999154128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999160272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999160656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999161040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999160848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999156048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999162192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999162576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999162960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999162768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999157968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999164112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999164880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999163344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136926999166032: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved gender_model_from_saved.tflite
# W0000 00:00:1756594922.455863      36 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1756594922.455901      36 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1756594922.602236      36 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled

# %%
# evaluation

print("\n--- Evaluating on Test Set ---")
y_pred_probs = gender_model.predict(test_ds)
y_pred = (y_pred_probs > 0.5).astype("int32")
y_true = np.concatenate([y for _, y in test_ds], axis=0)

print(classification_report(y_true, y_pred, target_names=['Male', 'Female']))
# Out:
# --- Evaluating on Test Set ---
# 419/419 ━━━━━━━━━━━━━━━━━━━━ 28s 58ms/step
#               precision    recall  f1-score   support
#
#         Male       0.91      0.91      0.91      6706
#       Female       0.91      0.91      0.91      6690
#
#     accuracy                           0.91     13396
#    macro avg       0.91      0.91      0.91     13396
# weighted avg       0.91      0.91      0.91     13396
